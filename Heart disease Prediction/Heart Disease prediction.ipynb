# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("heart.csv")

# %%
a=df.groupby(['Sex','Age'])
a.first()
# Out:
#         ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# Sex Age
# F   30             TA        170          237          0         ST    170
#     31            ATA        100          219          0         ST    150
#     32            ATA        105          198          0     Normal    165
#     33            ASY        100          246          0     Normal    150
#     34            ATA        130          161          0     Normal    190
# ...               ...        ...          ...        ...        ...    ...
# M   72            NAP        160            0          0        LVH    114
#     74            ATA        145            0          1         ST    123
#     75            ASY        170          203          1         ST    108
#     76            NAP        104          113          0        LVH    120
#     77            ASY        124          171          0         ST    110
#
#         ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %%
pd.crosstab(df.Age,df.HeartDisease,margins=True)
# Out:
# HeartDisease    0    1  All
# Age
# 28              1    0    1
# 29              3    0    3
# 30              1    0    1
# 31              1    1    2
# 32              3    2    5
# 33              1    1    2
# 34              5    2    7
# 35              7    4   11
# 36              4    2    6
# 37             10    1   11
# 38              5   11   16
# 39             13    2   15
# 40              7    6   13
# 41             18    6   24
# 42             15    3   18
# 43             13   11   24
# 44             13    6   19
# 45             15    3   18
# 46             11   13   24
# 47              8   11   19
# 48             16   15   31
# 49             10   11   21
# 50             11   14   25
# 51             20   15   35
# 52             17   19   36
# 53             18   15   33
# 54             28   23   51
# 55             17   24   41
# 56             13   25   38
# 57             12   26   38
# 58             14   28   42
# 59             12   23   35
# ...

# %%
df.hist(column="Age",by="HeartDisease",bins=30)
# Out:
# array([<AxesSubplot:title={'center':'0'}>,
#        <AxesSubplot:title={'center':'1'}>], dtype=object)

# %%
df.sort_values(by="Age",ascending=False,inplace=True)

# %%
pd.pivot_table(df,index=['Age','Sex'],values="HeartDisease")
# Out:
#          HeartDisease
# Age Sex
# 28  M        0.000000
# 29  M        0.000000
# 30  F        0.000000
# 31  F        0.000000
#     M        1.000000
# ...               ...
# 74  M        0.833333
# 75  M        0.666667
# 76  F        0.000000
#     M        1.000000
# 77  M        1.000000
#
# [91 rows x 1 columns]

# %%
df.head()
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 814   77   M           ASY        125          304          0        LVH
# 447   77   M           ASY        124          171          0         ST
# 688   76   F           NAP        140          197          0         ST
# 541   76   M           NAP        104          113          0        LVH
# 556   75   M           ASY        160          310          1     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 814    162              Y      0.0       Up             1
# 447    110              Y      2.0       Up             1
# 688    116              N      1.1     Flat             0
# 541    120              N      3.5     Down             1
# 556    112              Y      2.0     Down             0

# %%
df.head()
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 814   77   M           ASY        125          304          0        LVH
# 447   77   M           ASY        124          171          0         ST
# 688   76   F           NAP        140          197          0         ST
# 541   76   M           NAP        104          113          0        LVH
# 556   75   M           ASY        160          310          1     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 814    162              Y      0.0       Up             1
# 447    110              Y      2.0       Up             1
# 688    116              N      1.1     Flat             0
# 541    120              N      3.5     Down             1
# 556    112              Y      2.0     Down             0

# %%
pd.pivot_table(df,index=['Age','Sex'],values="HeartDisease",aggfunc=[np.mean,min,max])
# Out:
#                 mean          min          max
#         HeartDisease HeartDisease HeartDisease
# Age Sex
# 28  M       0.000000            0            0
# 29  M       0.000000            0            0
# 30  F       0.000000            0            0
# 31  F       0.000000            0            0
#     M       1.000000            1            1
# ...              ...          ...          ...
# 74  M       0.833333            0            1
# 75  M       0.666667            0            1
# 76  F       0.000000            0            0
#     M       1.000000            1            1
# 77  M       1.000000            1            1
#
# [91 rows x 3 columns]

# %%
df.sort_index()
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %% [markdown]
# ### Method
# - df.method()
#
# ### attribute
# - df.attribute

# %%
df.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
 df.plot.scatter(x='Age',y='Oldpeak')
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Oldpeak'>

# %%
df.tail()
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 215   30   F            TA        170          237          0         ST
# 219   29   M           ATA        140          263          0     Normal
# 829   29   M           ATA        130          204          0        LVH
# 170   29   M           ATA        120          243          0     Normal
# 208   28   M           ATA        130          132          0        LVH
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 215    170              N      0.0       Up             0
# 219    170              N      0.0       Up             0
# 829    202              N      0.0       Up             0
# 170    160              N      0.0       Up             0
# 208    185              N      0.0       Up             0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 918 entries, 814 to 208
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             918 non-null    int64
#  1   Sex             918 non-null    object
#  2   ChestPainType   918 non-null    object
#  3   RestingBP       918 non-null    int64
#  4   Cholesterol     918 non-null    int64
#  5   FastingBS       918 non-null    int64
#  6   RestingECG      918 non-null    object
#  7   MaxHR           918 non-null    int64
#  8   ExerciseAngina  918 non-null    object
#  9   Oldpeak         918 non-null    float64
#  10  ST_Slope        918 non-null    object
#  11  HeartDisease    918 non-null    int64
# dtypes: float64(1), int64(6), object(5)
# memory usage: 75.3+ KB

# %%
df.shape
# Out:
# (918, 12)

# %%
df.describe()
# Out:
#               Age   RestingBP  Cholesterol   FastingBS       MaxHR  \
# count  918.000000  918.000000   918.000000  918.000000  918.000000
# mean    53.510893  132.396514   198.799564    0.233115  136.809368
# std      9.432617   18.514154   109.384145    0.423046   25.460334
# min     28.000000    0.000000     0.000000    0.000000   60.000000
# 25%     47.000000  120.000000   173.250000    0.000000  120.000000
# 50%     54.000000  130.000000   223.000000    0.000000  138.000000
# 75%     60.000000  140.000000   267.000000    0.000000  156.000000
# max     77.000000  200.000000   603.000000    1.000000  202.000000
#
#           Oldpeak  HeartDisease
# count  918.000000    918.000000
# mean     0.887364      0.553377
# std      1.066570      0.497414
# min     -2.600000      0.000000
# 25%      0.000000      0.000000
# 50%      0.600000      1.000000
# 75%      1.500000      1.000000
# max      6.200000      1.000000

# %%
df.max()
# Out:
# Age                77
# Sex                 M
# ChestPainType      TA
# RestingBP         200
# Cholesterol       603
# FastingBS           1
# RestingECG         ST
# MaxHR             202
# ExerciseAngina      Y
# Oldpeak           6.2
# ST_Slope           Up
# HeartDisease        1
# dtype: object

# %%
df.iloc[2:100,:]
# Out:
#     Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 2    37   M           ATA        130          283          0         ST
# 3    48   F           ASY        138          214          0     Normal
# 4    54   M           NAP        150          195          0     Normal
# 5    39   M           NAP        120          339          0     Normal
# 6    45   F           ATA        130          237          0     Normal
# ..  ...  ..           ...        ...          ...        ...        ...
# 95   58   M           ASY        130          263          0     Normal
# 96   43   M           ATA        142          207          0     Normal
# 97   39   M           NAP        160          147          1     Normal
# 98   56   M           ASY        120           85          0     Normal
# 99   41   M           ATA        125          269          0     Normal
#
#     MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %%
df.dtypes.value_counts()
# Out:
# int64      6
# object     5
# float64    1
# dtype: int64

# %%
df[df.isnull().any(axis=1)].head()
# Out:
# Empty DataFrame
# Columns: [Age, Sex, ChestPainType, RestingBP, Cholesterol, FastingBS, RestingECG, MaxHR, ExerciseAngina, Oldpeak, ST_Slope, HeartDisease]
# Index: []

# %%
df.dtypes
# Out:
# Age                 int64
# Sex                object
# ChestPainType      object
# RestingBP           int64
# Cholesterol         int64
# FastingBS           int64
# RestingECG         object
# MaxHR               int64
# ExerciseAngina     object
# Oldpeak           float64
# ST_Slope           object
# HeartDisease        int64
# dtype: object

# %%
df2 = df.copy()

# %%
df.shape
# Out:
# (918, 12)

# %%
df.sample()
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 893   57   M           ATA        154          232          0        LVH
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 893    164              N      0.0       Up             1

# %%
df1=df.head(50)

# %%
df1.mean()
# Out:
# Age              46.28
# RestingBP       128.24
# Cholesterol     245.08
# FastingBS         0.04
# MaxHR           140.90
# Oldpeak           0.58
# HeartDisease      0.32
# dtype: float64

# %%
df.std()
# Out:
# Age               9.432617
# RestingBP        18.514154
# Cholesterol     109.384145
# FastingBS         0.423046
# MaxHR            25.460334
# Oldpeak           1.066570
# HeartDisease      0.497414
# dtype: float64

# %%
df.RestingBP.describe()
# Out:
# count    918.000000
# mean     132.396514
# std       18.514154
# min        0.000000
# 25%      120.000000
# 50%      130.000000
# 75%      140.000000
# max      200.000000
# Name: RestingBP, dtype: float64

# %%
df.RestingBP.count()
# Out:
# 918

# %%
 d=df.groupby(['RestingBP'])

# %%
d.Age.mean()
# Out:
# RestingBP
# 0      55.000000
# 80     53.000000
# 92     38.000000
# 94     45.000000
# 95     49.333333
#          ...
# 180    56.333333
# 185    63.000000
# 190    50.000000
# 192    54.000000
# 200    58.750000
# Name: Age, Length: 67, dtype: float64

# %%
df.kurt()
# Out:
# Age            -0.386140
# RestingBP       3.271251
# Cholesterol     0.118208
# FastingBS      -0.401960
# MaxHR          -0.448248
# Oldpeak         1.203064
# HeartDisease   -1.958008
# dtype: float64
